# %%
import requests
import json
# Out:
# /Users/subhankumarrai/Desktop/ml-churn-prediction-system/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
API_URL = "http://127.0.0.1:8000/predict"

# %%
payload = {
    "tenure": 12,
    "MonthlyCharges": 70.5,
    "TotalCharges": 850.0,
    "Contract": "Month-to-month",
    "PaymentMethod": "Electronic check",
    "InternetService": "Fiber optic",
    "SeniorCitizen": 0,
    "Partner": "Yes",
    "Dependents": "No",
    "PaperlessBilling": "Yes"
}

# %%
response = requests.post(API_URL, json=payload)
response.status_code, response.json()
# Out:
# (200, {'churn_probability': 0.5591, 'churn_prediction': 1, 'threshold': 0.3})

# %%
bad_payload = {
    "tenure": -5,
    "MonthlyCharges": -100,
    "TotalCharges": 0,
    "Contract": "Weekly",
    "PaymentMethod": "Cash",
    "InternetService": "Unknown",
    "SeniorCitizen": 2,
    "Partner": "Maybe",
    "Dependents": "No",
    "PaperlessBilling": "Yes"
}

response = requests.post(API_URL, json=bad_payload)
response.status_code, response.text
# Out:
# (422,
#  '{"detail":[{"type":"greater_than_equal","loc":["body","tenure"],"msg":"Input should be greater than or equal to 0","input":-5,"ctx":{"ge":0}},{"type":"greater_than_equal","loc":["body","MonthlyCharges"],"msg":"Input should be greater than or equal to 0","input":-100,"ctx":{"ge":0.0}},{"type":"literal_error","loc":["body","Contract"],"msg":"Input should be \'Month-to-month\', \'One year\' or \'Two year\'","input":"Weekly","ctx":{"expected":"\'Month-to-month\', \'One year\' or \'Two year\'"}},{"type":"literal_error","loc":["body","PaymentMethod"],"msg":"Input should be \'Electronic check\', \'Mailed check\', \'Bank transfer (automatic)\' or \'Credit card (automatic)\'","input":"Cash","ctx":{"expected":"\'Electronic check\', \'Mailed check\', \'Bank transfer (automatic)\' or \'Credit card (automatic)\'"}},{"type":"literal_error","loc":["body","InternetService"],"msg":"Input should be \'DSL\', \'Fiber optic\' or \'No\'","input":"Unknown","ctx":{"expected":"\'DSL\', \'Fiber optic\' or \'No\'"}},{"type":"literal_error","loc":["body","SeniorCitizen"],"msg":"Input should be 0 or 1","input":2,"ctx":{"expected":"0 or 1"}},{"type":"literal_error","loc":["body","Partner"],"msg":"Input should be \'Yes\' or \'No\'","input":"Maybe","ctx":{"expected":"\'Yes\' or \'No\'"}}]}')
